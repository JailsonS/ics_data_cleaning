# %%
import pandas as pd

# %%
df = pd.read_parquet('data/banco_carnes_un_v2_ed.parquet')

# %%
df.groupby(by=['codigo', 'has_change']).count()
# Out:
#                       ...1      ano       UF  municipio  dados.fornecedor  \
# codigo has_change
# 1      0                90       90       90         90                90
# 11     0           2258621  2258621  2258621    2258621           2258621
# 12     0            261493   261493   261493     261493            261493
# 13     0             13398    13398    13398      13398             13398
# 14     0           1846912  1846912  1846912    1846912           1846912
# 15     0            360352   360352   360352     360352            360352
# 16     0            119340   119340   119340     119340            119340
# 17     0             23776    23776    23776      23776             23776
# 18     0             14173    14173    14173      14173             14173
# 21     0             57650    57650    57650      57650             57650
# 22     0            886284   886284   886284     886284            886284
# ...
